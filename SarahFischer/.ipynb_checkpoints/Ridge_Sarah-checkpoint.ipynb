# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Scikit-Learn: Core Workflow
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Load Data

# %%
REPO_DIR = Path("..")
DATA_DIR = REPO_DIR / "Data"

X_train = pd.read_csv(DATA_DIR / "X_train.csv", index_col=0)
X_test = pd.read_csv(DATA_DIR / "X_test.csv", index_col=0)
y_train = pd.read_csv(DATA_DIR / "y_train.csv", index_col=0).squeeze("columns")
y_test = pd.read_csv(DATA_DIR / "y_test.csv", index_col=0).squeeze("columns")

# %% [markdown]
# ### Create Ridge Pipline & Analysis

# %%
# 5-fold CV setup
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# Pipeline
ridge_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('scaler', StandardScaler()),
    ('ridge', Ridge())
])

# Alpha grid
param_grid = {
    'ridge__alpha': np.logspace(-4, 4, 100)
}

# GridSearch with 5-fold CV
ridge_cv = GridSearchCV(
    ridge_pipe,
    param_grid=param_grid,
    cv=cv,
    scoring='neg_mean_squared_error'
)

# Fit model
ridge_cv.fit(X_train, y_train)

# Predictions
y_train_pred = ridge_cv.predict(X_train)
y_test_pred = ridge_cv.predict(X_test)

# Compute RMSE 
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

print("Best alpha:", ridge_cv.best_params_['ridge__alpha'])
print("RMSE:", rmse)
print("Train R^2:", r2_score(y_train, y_train_pred))
print("Test R^2:", r2_score(y_test, y_test_pred))
# Out:
# Best alpha: 138.48863713938746
# RMSE: 0.1375609305135601
# Train R^2: 0.6877321064002477
# Test R^2: 0.6434112392890766

# %% [markdown]
# ### CV Error vs Alpha

# %%
results = pd.DataFrame(ridge_cv.cv_results_)

plt.figure()
plt.plot(param_grid['ridge__alpha'], -results['mean_test_score'])
plt.xscale('log')
plt.xlabel("Alpha (log scale)")
plt.ylabel("CV MSE")
plt.title("Ridge Regression: Alpha vs Cross-Validated Error")
plt.show()

# %% [markdown]
# ### Top 20 Ridge Coefficients

# %%
best_ridge = ridge_cv.best_estimator_.named_steps['ridge']

coef = pd.Series(best_ridge.coef_, index=X_train.columns)
top_coef = coef.sort_values(key=np.abs, ascending=False).head(20)

plt.figure(figsize=(8,6))
top_coef.plot(kind='barh')
plt.title("Top 20 Ridge Coefficients")
plt.ylabel("Coefficient Value")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Report

# %% [markdown]
# The Ridge Regression model was trained using the Communities and Crime dataset from the UCI Machine Learning Repository to predict the rate of violent crimes per population across various U.S. communities. To find the best version of the model, we used cross-validation to test different "alpha" values, which control how much the model penalizes large coefficients to prevent overfitting. As shown in the first chart, the error starts high when the penalty is too small, drops to its lowest point at an alpha of about 138.49, and then climbs sharply as the penalty becomes too aggressive and causes the model to underfit. This specific alpha value allowed the model to explain about 68.8% of the variance in the training data and roughly 64.3% in the test data. The fact that these two scores are close together indicates that the model is stable and likely to perform consistently on new, unseen data.
#
# The second chart highlights which specific community factors had the biggest impact on the predictions. Socioeconomic and family-related variables emerged as the strongest predictors. For example, communities with a higher percentage of children living in two-parent households (PctKids2Par) or a higher percentage of white residents (racePctWhite) were associated with lower predicted crime rates. Conversely, factors like the percentage of the population that is black (racepctblack), the percentage of kids born to never-married parents (PctIlleg), and high housing density (PctPersDenseHous) showed a strong positive relationship with higher crime rates. With a final Root Mean Squared Error (RMSE) of 0.1376, the model provides a reasonably accurate way to understand how these different demographic and economic conditions relate to community safety.
